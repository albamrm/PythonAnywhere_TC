# %%
import pandas as pd

df = pd.read_csv('data/penguins.csv')

df.head()
# Out:
#    species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0        0       2            39.1           18.7              181.0
# 1        0       2            39.5           17.4              186.0
# 2        0       2            40.3           18.0              195.0
# 3        0       2            36.7           19.3              193.0
# 4        0       2            39.3           20.6              190.0
#
#    body_mass_g  sex
# 0       3750.0    1
# 1       3800.0    0
# 2       3250.0    0
# 3       3450.0    0
# 4       3650.0    1

# %%
df[df['species'] == 0]
# Out:
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0          0       2            39.1           18.7              181.0
# 1          0       2            39.5           17.4              186.0
# 2          0       2            40.3           18.0              195.0
# 3          0       2            36.7           19.3              193.0
# 4          0       2            39.3           20.6              190.0
# ..       ...     ...             ...            ...                ...
# 141        0       1            36.6           18.4              184.0
# 142        0       1            36.0           17.8              195.0
# 143        0       1            37.8           18.1              193.0
# 144        0       1            36.0           17.1              187.0
# 145        0       1            41.5           18.5              201.0
#
#      body_mass_g  sex
# 0         3750.0    1
# 1         3800.0    0
# 2         3250.0    0
# ...

# %%
df[df['species'] == 1]
# Out:
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 146        1       1            46.5           17.9              192.0
# 147        1       1            50.0           19.5              196.0
# 148        1       1            51.3           19.2              193.0
# 149        1       1            45.4           18.7              188.0
# 150        1       1            52.7           19.8              197.0
# ..       ...     ...             ...            ...                ...
# 209        1       1            55.8           19.8              207.0
# 210        1       1            43.5           18.1              202.0
# 211        1       1            49.6           18.2              193.0
# 212        1       1            50.8           19.0              210.0
# 213        1       1            50.2           18.7              198.0
#
#      body_mass_g  sex
# 146       3500.0    0
# 147       3900.0    1
# 148       3650.0    1
# ...

# %%
df[df['species'] == 2]
# Out:
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 214        2       0            46.1           13.2              211.0
# 215        2       0            50.0           16.3              230.0
# 216        2       0            48.7           14.1              210.0
# 217        2       0            50.0           15.2              218.0
# 218        2       0            47.6           14.5              215.0
# ..       ...     ...             ...            ...                ...
# 328        2       0            47.2           13.7              214.0
# 329        2       0            46.8           14.3              215.0
# 330        2       0            50.4           15.7              222.0
# 331        2       0            45.2           14.8              212.0
# 332        2       0            49.9           16.1              213.0
#
#      body_mass_g  sex
# 214       4500.0    0
# 215       5700.0    1
# 216       4450.0    0
# ...

# %%
valor_minimo = df['bill_length_mm'].min()

valor_maximo = df['bill_length_mm'].max()

print(f"El valor mínimo de la columna 'bill_length_mm' es: {valor_minimo}")
print(f"El valor máximo de la columna 'bill_length_mm' es: {valor_maximo}")
# Out:
# El valor mínimo de la columna 'bill_length_mm' es: 32.1
# El valor máximo de la columna 'bill_length_mm' es: 59.6

# %%
valor_minimo = df['bill_depth_mm'].min()

valor_maximo = df['bill_depth_mm'].max()

print(f"El valor mínimo de la columna 'bill_depth_mm' es: {valor_minimo}")
print(f"El valor máximo de la columna 'bill_depth_mm' es: {valor_maximo}")
# Out:
# El valor mínimo de la columna 'bill_depth_mm' es: 13.1
# El valor máximo de la columna 'bill_depth_mm' es: 21.5

# %%
valor_minimo = df['flipper_length_mm'].min()

valor_maximo = df['flipper_length_mm'].max()

print(f"El valor mínimo de la columna 'flipper_length_mm' es: {valor_minimo}")
print(f"El valor máximo de la columna 'flipper_length_mm' es: {valor_maximo}")
# Out:
# El valor mínimo de la columna 'flipper_length_mm' es: 172.0
# El valor máximo de la columna 'flipper_length_mm' es: 231.0

# %%
valor_minimo = df['body_mass_g'].min()

valor_maximo = df['body_mass_g'].max()

print(f"El valor mínimo de la columna 'body_mass_g' es: {valor_minimo}")
print(f"El valor máximo de la columna 'body_mass_g' es: {valor_maximo}")
# Out:
# El valor mínimo de la columna 'body_mass_g' es: 2700.0
# El valor máximo de la columna 'body_mass_g' es: 6300.0
